# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(12,8)})

# %%
train = pd.read_csv("../data/X_train_ini.csv")
test = pd.read_csv("../data/test.csv")
fold_1 = pd.read_csv("../data/fold/fold_1.csv")

# %%
fold_1
# Out:
#        Store  Dept        Date  Weekly_Sales  IsHoliday
# 0          1     1  2011-03-04      20327.61      False
# 1          1     1  2011-03-11      21280.40      False
# 2          1     1  2011-03-18      20334.23      False
# 3          1     1  2011-03-25      20881.10      False
# 4          1     1  2011-04-01      20398.09      False
# ...      ...   ...         ...           ...        ...
# 26554     45    98  2011-04-01        991.32      False
# 26555     45    98  2011-04-08       1301.43      False
# 26556     45    98  2011-04-15        980.06      False
# 26557     45    98  2011-04-22       1058.62      False
# 26558     45    98  2011-04-29        868.74      False
#
# [26559 rows x 5 columns]

# %%
train['IsHoliday_oh'] = train['IsHoliday'].astype(int)
#Extract Year, Month, Week, Date (Train)
train['day'] = pd.to_datetime(train['Date']).dt.day
train['week'] = pd.to_datetime(train['Date']).dt.week
train['month'] = pd.to_datetime(train['Date']).dt.month
train['year'] = pd.to_datetime(train['Date']).dt.year

# %%
sns.lineplot(data=train,x='Date',y='Weekly_Sales',hue='year')

# %%
sns.lineplot(data=train,x='Date',y='Weekly_Sales',hue='Store')

# %%
sns.lineplot(data=fold_1,x='Date',y='Weekly_Sales')

# %%
sns.lineplot(data=fold_1,x='Date',y='Weekly_Sales',hue='Store')

# %%
from sklearn import preprocessing
from tpot import TPOTRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-dbe73e6f92fa> in <module>
#       1 from sklearn import preprocessing
# ----> 2 from tpot import TPOTRegressor
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tpot/__init__.py in <module>
#      25
#      26 from ._version import __version__
# ---> 27 from .tpot import TPOTClassifier, TPOTRegressor
#      28 from .driver import main
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tpot/tpot.py in <module>
#      24 """
#      25
# ---> 26 from .base import TPOTBase
#      27 from .config.classifier import classifier_config_dict
#      28 from .config.regressor import regressor_config_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tpot/base.py in <module>
#      50 from sklearn.externals.joblib import Parallel, delayed, Memory
#      51 from sklearn.pipeline import make_pipeline, make_union
# ...
