# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class CoordinateDescentLasso:
    def __init__(self, lamda: float = 1.0, max_iter: int = 1000, fit_intercept: bool = True) -> None:
        self.lamda: float = lamda
        self.max_iter: int = max_iter
        self.fit_intercept: bool = fit_intercept
        self.coef_ = None
        self.intercept_ = None

        
    def _lasso_threshold(self, x: float, lambda_: float) -> float:
        if x > 0.0 and lambda_ < abs(x):
            return x - lambda_
        elif x < 0.0 and lambda_ < abs(x):
            return x + lambda_
        else:
            return 0.0
        
        
    def Lasso_fit(self,X,y):
        if self.fit_intercept:
            X = np.column_stack((np.ones(len(X)), X))
            
        beta = np.zeros(X.shape[1])
        if self.fit_intercept:
            beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])
            
        for iteration in range(self.max_iter):
            start = 1 if self.fit_intercept else 0
            for j in range(start, len(beta)):
                tmp_beta = beta.copy()
                tmp_beta[j] = 0.0
                r_j = y - np.dot(X, tmp_beta)
                arg1 = np.dot(X[:, j], r_j)
                arg2 = self.lamda * X.shape[0]
                
                beta[j] = self._lasso_threshold(arg1, arg2) / (X[:, j]**2).sum()
                
                if self.fit_intercept:
                    beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])

        if self.fit_intercept:
            self.intercept_ = beta[0]
            self.coef_ = beta[1:]
        else:
            self.coef_ = beta

        return self     


if __name__ == "__main__":
    #Load the datasets
    dataset = pd.read_csv("/users/Sushanta/Documents/GitHub/Illinois/CS598 Practical Statistical Learning/Coding2_myData.csv")
    X = np.array(dataset[dataset.columns[:-1]])
    y = np.array(dataset['Y'])
    feature_names = dataset.columns
    
    #Standardize the X, Mean 0, and Std
    X = (X - X.mean(axis=0, keepdims=True)) / X.std(axis=0, keepdims=True)
    
    m,n = X.shape
    #initial_theta = np.ones((n,1))
    theta_list_scratch = list()
    theta_list_sklearn = list()
    
    #Define the lamda values
    log_lam_seq = np.linspace(-1, -8, num = 80)
    lam_seq = np.exp(log_lam_seq)
    i = 1
    
    #Loop for each Lamda, there are 80 Lamda
    for l in lam_seq:
        if (np.mod(i,10) == 0):
            print ("Processing for Lamda Sequence - {}".format(i))
            
        model_scratch = CoordinateDescentLasso(lamda=l)
        model_scratch.Lasso_fit(X, y)
        theta_list_scratch.append(model_scratch.coef_)
        
        model_sklearn = Lasso(alpha=l)
        model_sklearn.fit(X,y)
        theta_list_sklearn.append(model_sklearn.coef_)
        
        i=i+1
        
    theta_scratch = np.stack(theta_list_scratch).T
    theta_sklearn = np.stack(theta_list_sklearn).T
    
    p, _ = theta_scratch.shape
    plt.figure(figsize = (12,8))
    
    for i in range(p):
        plt.plot(log_lam_seq, theta_scratch[i, :], label = dataset.columns[i])

    plt.xlabel('Log Lambda')
    plt.ylabel('Coefficients')
    plt.title('Lasso Paths - Numpy implementation')
    plt.legend()
    plt.axis('tight')    
    

    plt.figure(figsize = (12,8))
    
    for i in range(p):
        plt.plot(log_lam_seq, theta_sklearn[i, :], label = dataset.columns[i])

    plt.xlabel('Log Lambda')
    plt.ylabel('Coefficients')
    plt.title('Lasso Paths - Sklearn implementation')
    plt.legend()
    plt.axis('tight')
    
    
    print ("Differnece between Numpy Implementation & Sklearn Implementation - Thea Absoulute value is: {}".format(abs(theta_scratch - theta_sklearn).max()))
# Out:
# Processing for Lamda Sequence - 10
# Processing for Lamda Sequence - 20
# Processing for Lamda Sequence - 30
# Processing for Lamda Sequence - 40
# Processing for Lamda Sequence - 50
# Processing for Lamda Sequence - 60
# Processing for Lamda Sequence - 70
# Processing for Lamda Sequence - 80
# Differnece between Numpy Implementation & Sklearn Implementation - Thea Absoulute value is: 0.0001778114044362379

# %%
class CoordinateDescentLasso:
    def __init__(self, alpha: float = 1.0, max_iter: int = 1000, fit_intercept: bool = True) -> None:
        self.alpha: float = alpha  # 正則化項の係数
        self.max_iter: int = max_iter  # 繰り返しの回数
        self.fit_intercept: bool = fit_intercept  # 切片(i.e., \beta_0)を用いるか
        self.coef_ = None  # 回帰係数(i.e., \beta)保存用変数
        self.intercept_ = None  # 切片保存用変数

    def _soft_thresholding_operator(self, x: float, lambda_: float) -> float:
        if x > 0.0 and lambda_ < abs(x):
            return x - lambda_
        elif x < 0.0 and lambda_ < abs(x):
            return x + lambda_
        else:
            return 0.0

    def fit(self, X: np.ndarray, y: np.ndarray):
        
        if self.fit_intercept:
            X = np.column_stack((np.ones(len(X)), X))

        beta = np.zeros(X.shape[1])
        if self.fit_intercept:
            beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])

        for iteration in range(self.max_iter):
            start = 1 if self.fit_intercept else 0
            for j in range(start, len(beta)):
                tmp_beta = beta.copy()
                tmp_beta[j] = 0.0
                r_j = y - np.dot(X, tmp_beta)
                arg1 = np.dot(X[:, j], r_j)
                arg2 = self.alpha * X.shape[0]

                beta[j] = self._soft_thresholding_operator(arg1, arg2) / (X[:, j]**2).sum()

                if self.fit_intercept:
                    beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])

        if self.fit_intercept:
            self.intercept_ = beta[0]
            self.coef_ = beta[1:]
        else:
            self.coef_ = beta

        return self


if __name__ == "__main__":
    #Load the datasets
    dataset = pd.read_csv("/users/Sushanta/Documents/GitHub/Illinois/CS598 Practical Statistical Learning/Coding2_myData.csv")
    X = np.array(dataset[dataset.columns[:-1]])
    y = np.array(dataset['Y'])
    feature_names = dataset.columns
    
    #Standardize the X, Mean 0, and Std
    X = (X - X.mean(axis=0, keepdims=True)) / X.std(axis=0, keepdims=True)
    
    m,n = X.shape
    #initial_theta = np.ones((n,1))
    theta_list_scratch = list()
    theta_list_sklearn = list()
    
    #Define the lamda values
    log_lam_seq = np.linspace(-1, -8, num = 80)
    lam_seq = np.exp(log_lam_seq)
    i = 1
    
    #Loop for each Lamda, there are 80 Lamda
    for l in lam_seq:
        if (np.mod(i,10) == 0):
            print ("Processing for Lamda Sequence - {}".format(i))
            
        model_scratch = CoordinateDescentLasso(alpha=l)
        model_scratch.fit(X, y)
        theta_list_scratch.append(model_scratch.coef_)
        
        model_sklearn = Lasso(alpha=l)
        model_sklearn.fit(X,y)
        theta_list_sklearn.append(model_sklearn.coef_)
        
        i=i+1
        
    theta_scratch = np.stack(theta_list_scratch).T
    theta_sklearn = np.stack(theta_list_sklearn).T
    
    p, _ = theta_scratch.shape
    plt.figure(figsize = (12,8))
    
    for i in range(p):
        plt.plot(log_lam_seq, theta_scratch[i, :], label = dataset.columns[i])

    plt.xlabel('Log Lambda')
    plt.ylabel('Coefficients')
    plt.title('Lasso Paths - Numpy implementation')
    plt.legend()
    plt.axis('tight')

# %%
if __name__ == "__main__":
    #Load the datasets
    dataset = pd.read_csv("/users/Sushanta/Documents/GitHub/Illinois/CS598 Practical Statistical Learning/Coding2_myData.csv")
    X = np.array(dataset[dataset.columns[:-1]])
    y = np.array(dataset['Y'])
    feature_names = dataset.columns

    #Standardize the X, Mean 0, and Std
    X = (X - X.mean(axis=0, keepdims=True)) / X.std(axis=0, keepdims=True)
    
    m,n = X.shape
    #initial_theta = np.ones((n,1))
    theta_list_scratch = list()
    theta_list_sklearn = list()
    
    #Define the lamda values
    log_lam_seq = np.linspace(-1, -8, num = 80)
    lam_seq = np.exp(log_lam_seq)
    i = 1
    
    #Loop for each Lamda, there are 80 Lamda
    for l in lam_seq:
        if (np.mod(i,10) == 0):
            print ("Processing for Lamda Sequence - {}".format(i))
            
        model_scratch = CoordinateDescentLasso(alpha=l)
        model_scratch.fit(X, y)
        theta_list_scratch.append(model_scratch.coef_)
        
        #model_sklearn = Lasso(alpha=l)
        #model_sklearn.fit(X,y)
        #theta_list_sklearn.append(model.coef_)
        
        i=i+1
        

        
        
    theta_scratch = np.stack(theta_list_scratch).T

    p, _ = theta_scratch.shape
    plt.figure(figsize = (12,8))
    
    for i in range(p):
        plt.plot(log_lam_seq, theta_scratch[i, :], label = dataset.columns[i])
        
    plt.xlabel('Log Lambda')
    plt.ylabel('Coefficients')
    plt.title('Lasso Paths - Numpy implementation')
    plt.legend()
    plt.axis('tight')

# %%
#
# Copyright (c) 2016-2021 Minato Sato
# All rights reserved.
#
# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
#

import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler


class CoordinateDescentLasso:
    def __init__(self, alpha: float = 1.0, max_iter: int = 1000, fit_intercept: bool = True) -> None:
        self.alpha: float = alpha  # 正則化項の係数
        self.max_iter: int = max_iter  # 繰り返しの回数
        self.fit_intercept: bool = fit_intercept  # 切片(i.e., \beta_0)を用いるか
        self.coef_ = None  # 回帰係数(i.e., \beta)保存用変数
        self.intercept_ = None  # 切片保存用変数

    def _soft_thresholding_operator(self, x: float, lambda_: float) -> float:
        if x > 0.0 and lambda_ < abs(x):
            return x - lambda_
        elif x < 0.0 and lambda_ < abs(x):
            return x + lambda_
        else:
            return 0.0

    def fit(self, X: np.ndarray, y: np.ndarray):
        
        if self.fit_intercept:
            X = np.column_stack((np.ones(len(X)), X))

        beta = np.zeros(X.shape[1])
        if self.fit_intercept:
            beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])

        for iteration in range(self.max_iter):
            start = 1 if self.fit_intercept else 0
            for j in range(start, len(beta)):
                tmp_beta = beta.copy()
                tmp_beta[j] = 0.0
                r_j = y - np.dot(X, tmp_beta)
                arg1 = np.dot(X[:, j], r_j)
                arg2 = self.alpha * X.shape[0]

                beta[j] = self._soft_thresholding_operator(arg1, arg2) / (X[:, j]**2).sum()

                if self.fit_intercept:
                    beta[0] = np.sum(y - np.dot(X[:, 1:], beta[1:])) / (X.shape[0])

        if self.fit_intercept:
            self.intercept_ = beta[0]
            self.coef_ = beta[1:]
        else:
            self.coef_ = beta

        return self

    def predict(self, X: np.ndarray):
        y = np.dot(X, self.coef_)
        if self.fit_intercept:
            y += self.intercept_ * np.ones(len(y))
        return y


if __name__ == "__main__":
    #Previous Code from the Original Code
    #dataset = datasets.load_boston()
    #X = dataset.data
    #y = dataset.target
    
    dataset = pd.read_csv("/users/Sushanta/Documents/GitHub/Illinois/CS598 Practical Statistical Learning/Coding2_myData.csv")
    X = np.array(dataset[dataset.columns[:-1]])
    y = np.array(dataset['Y'])

    X = (X - X.mean(axis=0, keepdims=True)) / X.std(axis=0, keepdims=True)
    
    m,n = X.shape
    initial_theta = np.ones((n,1))
    theta_list = list()
    
    #Define the lamda values
    log_lam_seq = np.linspace(-1, -8, num = 80)
    lam_seq = np.exp(log_lam_seq)
    i = 1
    
    for l in lam_seq:
        if (np.mod(i,10) == 0):
            print ("Processing for Lamda Sequence - {}".format(i))
        model = CoordinateDescentLasso(alpha=l)
        model.fit(X, y)
        theta_list.append(model.coef_)
        
        #print(model.intercept_)
        #print(model.coef_)
        
        i=i+1
        
    theta_lasso = np.stack(theta_list).T
    feature_names = dataset.columns
    p, _ = theta_lasso.shape
    plt.figure(figsize = (12,8))
    
    for i in range(p):
        plt.plot(log_lam_seq, theta_lasso[i, :], label = dataset.columns[i])
        
    plt.xlabel('Log Lambda')
    plt.ylabel('Coefficients')
    plt.title('Lasso Paths - Numpy implementation')
    plt.legend()
    plt.axis('tight')
    
    
    #model = CoordinateDescentLasso(alpha=1 / 2)
    #model.fit(X, y)

    #print(model.intercept_)
    #print(model.coef_)

# %%
model = Lasso(lam_seq[2])
model.fit(X, y)
model.coef_

# %%
theta_lasso[:,2]

# %%
from sklearn.linear_model import Lasso
m,n = X.shape
initial_theta = np.ones((n,1))
theta_list = list()

#Define the lamda values
log_lam_seq = np.linspace(-1, -8, num = 80)
lam_seq = np.exp(log_lam_seq)
i = 1

for l in lam_seq:
    if (np.mod(i,10) == 0):
        print ("Processing for Lamda Sequence - {}".format(i))
    model = CoordinateDescentLasso(alpha=l)
    model.fit(X, y)
    theta_list.append(model.coef_)

    #print(model.intercept_)
    #print(model.coef_)

    i=i+1

theta_lasso = np.stack(theta_list).T
feature_names = dataset.columns
p, _ = theta_lasso.shape
plt.figure(figsize = (12,8))

for i in range(p):
    plt.plot(log_lam_seq, theta_lasso[i, :], label = dataset.columns[i])

plt.xlabel('Log Lambda')
plt.ylabel('Coefficients')
plt.title('Lasso Paths - Numpy implementation')
plt.legend()
plt.axis('tight')

# %%
lasso_coef = np.genfromtxt("/users/Sushanta/Documents/GitHub/Illinois/CS598 Practical Statistical Learning/Coding2_lasso_coefs.csv", delimiter=',',skip_header=1)
lasso_coef.shape

# %%
abs(theta_lasso - lasso_coef[1:,:]).max()
