# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from scipy.stats import multivariate_normal

# %%
X = np.loadtxt('data/Old Faithful geyser.txt')
plt.figure(figsize=[6, 6])
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('Eruptions (minutes)')
plt.ylabel('Waiting time (minutes)')
plt.show()

# %%
def normalize_data(X):
    
    X_norm = np.zeros(X.shape)
    X_norm[:,0] = (X[:,0] - np.amin(X[:,0]))/(np.amax(X[:,0]) - np.amin(X[:,0]))
    X_norm[:,1] = (X[:,1] - np.amin(X[:,1]))/(np.amax(X[:,1]) - np.amin(X[:,1]))

    return X_norm

# %%
plt.figure(figsize=[6, 6])
X_norm = normalize_data(X)
plt.scatter(X_norm[:, 0], X_norm[:, 1]);

# %%
def gmm_log_likelihood(X, means, covs, mixing_coefs):
    
    sum2 = 0
    for i in range(X.shape[0]):
        sum1 = 0
        for k in range(mixing_coefs.shape[0]):
            sum1 += mixing_coefs[k] * multivariate_normal.pdf(X[i], mean=means[k], cov=covs[k])
        sum2 += np.log(sum1)
    log_likelihood = sum2
    
    return log_likelihood

# %%
def e_step(X, means, covs, mixing_coefs):
    
    responsibilities = np.zeros((X.shape[0],means.shape[0]))
    num = np.zeros(mixing_coefs.shape[0])
    denomin=0
    for n in range(X.shape[0]):
        denomin = 0
        for k in range(mixing_coefs.shape[0]):
            num[k] = mixing_coefs[k] * multivariate_normal.pdf(X[n,:], means[k,:],covs[k,:,:])
            denomin += mixing_coefs[k] * multivariate_normal.pdf(X[n,:], means[k,:],covs[k,:,:])
        for k in range(mixing_coefs.shape[0]):
            responsibilities[n,k] = num[k] / denomin
            
    return responsibilities

# %%
def m_step(X, responsibilities):

    N = np.zeros(responsibilities.shape[1])
    #iterate over clusters
    for k in range(responsibilities.shape[1]):
        #init
        N[k] = responsibilities[:,k].sum(axis=0)
        sum_mean = 0
        sum_cov = 0
        #new means
        for i in range(X.shape[0]):
            sum_mean += responsibilities[i,k] * X[i, :]
        sum_mean /= N[k]
        #new covs
        for i in range(X.shape[0]):
            A = X[i, :] - sum_mean
            sum_cov += responsibilities[i,k] *np.outer(A, A.T)
        means[k,:] = sum_mean
        covs[k,:,:] = sum_cov / N[k]
    NN = N.sum(axis=0)
    mixing_coefs = N / NN
    
    return means, covs, mixing_coefs

# %%
def plot_gmm_2d(X, responsibilities, means, covs, mixing_coefs):

    plt.figure(figsize=[6, 6])
    palette = np.array(sns.color_palette('colorblind', n_colors=3))[[0, 2]]
    colors = responsibilities.dot(palette)
    # Plot the samples colored according to p(z|x)
    plt.scatter(X[:, 0], X[:, 1], c=colors, alpha=0.5)
    # Plot locations of the means
    for ix, m in enumerate(means):
        plt.scatter(m[0], m[1], s=300, marker='X', c=palette[ix],
                    edgecolors='k', linewidths=1,)
    # Plot contours of the Gaussian
    x = np.linspace(0, 1, 50)
    y = np.linspace(0, 1, 50)
    xx, yy = np.meshgrid(x, y)
    for k in range(len(mixing_coefs)):
        zz = mlab.bivariate_normal(xx, yy, np.sqrt(covs[k][0, 0]),
                                   np.sqrt(covs[k][1, 1]), 
                                   means[k][0], means[k][1], covs[k][0, 1])
        plt.contour(xx, yy, zz, 2, colors='k')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.show()

# %%
covs = np.array([0.5 * np.eye(2), 0.5 * np.eye(2)])

# %%
means.shape
# Out:
# (3, 2)

# %%
means = np.array([[0.2, 0.6, 0.4], [0.8, 0.4, 0.6]])

# %%
means.shape
# Out:
# (2, 3)

# %%
means = np.array([[0.2, 0.6], [0.8, 0.4]])
covs = np.array([0.5 * np.eye(2), 0.5 * np.eye(2)])
mixing_coefs = np.array([0.5, 0.5])

# %%
means
# Out:
# array([[ 3.46775  ,  3.5078162],
#        [70.132353 , 71.6617647]])

# %%
means = np.array([[3.467750, 3.5078162], [70.132353, 71.6617647]])

# %%
# Initialize the parameters
means = np.array([[0.2, 0.6], [0.8, 0.4]])
covs = np.array([0.5 * np.eye(2), 0.5 * np.eye(2)])
#means = np.array([[3.467750, 3.5078162], [70.132353, 71.6617647]]) # This is "mean"
#covs = np.array([0.5 * np.eye(2), 0.5 * np.eye(2)]) # This is "Sigma"
mixing_coefs = np.array([0.5, 0.5]) # This is actual "prob"

# %%
responsibilities = e_step(X_norm, means, covs, mixing_coefs)

# %%
responsibilities.shape
# Out:
# (272, 2)

# %%
means
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
X_norm = normalize_data(X)
#X_norm = X
max_iters = 20

# Initialize the parameters
#means = np.array([[0.2, 0.6], [0.8, 0.4]])
#covs = np.array([0.5 * np.eye(2), 0.5 * np.eye(2)])
means = np.array([[3.467750,70.132353],[3.5078162,71.6617647]])
covs = np.array(([[[1.2975376,13.9110994],[13.911099,183.559040]]]*2))
mixing_coefs = np.array([0.5, 0.5]) # This is actual "prob"

old_log_likelihood = gmm_log_likelihood(X_norm, means, covs, mixing_coefs)
responsibilities = e_step(X_norm, means, covs, mixing_coefs)
print('At initialization: log-likelihood = {0}'
      .format(old_log_likelihood))
#plot_gmm_2d(X_norm, responsibilities, means, covs, mixing_coefs)

# Perform the EM iteration
for i in range(max_iters):
    responsibilities = e_step(X_norm, means, covs, mixing_coefs)
    means, covs, mixing_coefs = m_step(X_norm, responsibilities)
    new_log_likelihood = gmm_log_likelihood(X_norm, means, covs, mixing_coefs)
    # Report & visualize the optimization progress
    print('Iteration {0}: log-likelihood = {1:.2f}, improvement = {2:.2f}'
          .format(i, new_log_likelihood, new_log_likelihood - old_log_likelihood))
    old_log_likelihood = new_log_likelihood
    #plot_gmm_2d(X_norm, responsibilities, means, covs, mixing_coefs)
# Out:
# At initialization: log-likelihood = -7862.538530977446
# Iteration 0: log-likelihood = 130.90, improvement = 7993.44
# Iteration 1: log-likelihood = 130.91, improvement = 0.01
# Iteration 2: log-likelihood = 130.92, improvement = 0.01
# Iteration 3: log-likelihood = 130.93, improvement = 0.01
# Iteration 4: log-likelihood = 130.94, improvement = 0.01
# Iteration 5: log-likelihood = 130.96, improvement = 0.02
# Iteration 6: log-likelihood = 130.98, improvement = 0.02
# Iteration 7: log-likelihood = 131.01, improvement = 0.03
# Iteration 8: log-likelihood = 131.04, improvement = 0.03
# Iteration 9: log-likelihood = 131.08, improvement = 0.04
# Iteration 10: log-likelihood = 131.12, improvement = 0.05
# Iteration 11: log-likelihood = 131.18, improvement = 0.05
# Iteration 12: log-likelihood = 131.24, improvement = 0.07
# Iteration 13: log-likelihood = 131.32, improvement = 0.08
# Iteration 14: log-likelihood = 131.42, improvement = 0.10
# Iteration 15: log-likelihood = 131.53, improvement = 0.12
# Iteration 16: log-likelihood = 131.68, improvement = 0.14
# Iteration 17: log-likelihood = 131.86, improvement = 0.18
# Iteration 18: log-likelihood = 132.09, improvement = 0.23
# Iteration 19: log-likelihood = 132.39, improvement = 0.31

# %%
means
# Out:
# array([[0.5870699 , 0.56458055],
#        [0.37579847, 0.39530514]])

# %%
covs
# Out:
# array([[[0.0964498 , 0.06539876],
#         [0.06539876, 0.05680877]],
#
#        [[0.10398621, 0.0805656 ],
#         [0.0805656 , 0.07336005]]])

# %%
mixing_coefs
# Out:
# array([0.77420847, 0.22579153])
